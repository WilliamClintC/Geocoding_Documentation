# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\clint\Desktop\Geocoding_Documentation\Notebooks\8.csv')
df
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 4               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...                                                 ...
# 2328          2 530-824-8767 I-5 Exit 630 ( South Ave )
# 2329  CCorning 2530-824-8770 I-5 Exit 630 ( South Ave )
# 2330          2 530-824-8770 I-5 Exit 630 ( South Ave )
# 2331             530-436-2208 I-5 Exit 766 ( CA A12 E )
# 2332                     530-436-2208 I-5 Exit 766 ( CA
#
#                                       line3       city  zip_code  \
# 0                                        MO  Coalville     84017
# 1                                M <U+25A1>  Coalville     84017
# 2              M <U+2610> <U+2610> <U+2610>  Coalville     84017
# 3                       M <U+25A1> <U+2610>  Coalville     84017
# 4                          D M <U+25A1> D D  Coalville     84017
# ...                                     ...        ...       ...
# 2328                            24 XL 24 24    Corning     96021
# 2329                               XL 24 45        NaN     96021
# 2330                      124 HRS XL 24 HRS    Corning     96021
# 2331           <U+2610><U+2610> XL <U+2610>    Grenada     96038
# 2332  <U+2610><U+2610> XL <U+25A1> <U+2610>    Grenada     96038
#
#                                 label         phone  year major_city state  \
# 0                Holiday Hills ( 66 )  435-336-4421  2006  Coalville    UT
# 1                        Hills ( 66 )  435-336-4421  2007  Coalville    UT
# 2              Holiday Hills ( 66 ) )  435-336-4421  2008  Coalville    UT
# 3                Holiday Hills ( 66 )  435-336-4421  2014  Coalville    UT
# 4                Holiday Hills ( 66 )  435-336-4421  2015  Coalville    UT
# ...                               ...           ...   ...        ...   ...
# 2328         Love's Travel Stop # 410  530-824-8767  2016    Corning    CA
# 2329  Flying J Travel Plaza # 0510154  530-824-8770  2007    Corning    CA
# 2330  Flying J Travel Plaza # 0510154  530-824-8770  2008    Corning    CA
# 2331           3 J's Food Mart ( 76 )  530-436-2208  2014    Grenada    CA
# 2332      3 J's Food Mart ( 76 ) Dr )  530-436-2208  2015    Grenada    CA
#
#       ... max_distance_miles                 max_distance_sources  \
# 0     ...           1.828992  Yelp (Phone) vs YellowPages (Phone)
# 1     ...           1.828992  Yelp (Phone) vs YellowPages (Phone)
# 2     ...           1.828992  Yelp (Phone) vs YellowPages (Phone)
# 3     ...           1.828992  Yelp (Phone) vs YellowPages (Phone)
# 4     ...           1.828992  Yelp (Phone) vs YellowPages (Phone)
# ...   ...                ...                                  ...
# 2328  ...           0.108357  Yelp (Phone) vs YellowPages (Phone)
# 2329  ...           0.000000                                  NaN
# 2330  ...           0.000000                                  NaN
# 2331  ...           0.032823  Yelp (Phone) vs YellowPages (Phone)
# 2332  ...           0.032823  Yelp (Phone) vs YellowPages (Phone)
#
#      min_distance_miles                               min_distance_sources  \
# 0              0.000000  Truckstopsandservices (Phone) vs truckstopsand...
# 1              0.000000  Truckstopsandservices (Phone) vs truckstopsand...
# 2              0.000000  Truckstopsandservices (Phone) vs truckstopsand...
# 3              0.000000  Truckstopsandservices (Phone) vs truckstopsand...
# 4              0.000000  Truckstopsandservices (Phone) vs truckstopsand...
# ...                 ...                                                ...
# 2328           0.000000  Truckstopsandservices (Phone) vs truckstopsand...
# 2329           0.000000                                                NaN
# 2330           0.000000                                                NaN
# 2331           0.021885                Yelp (Phone) vs YellowPages (Phone)
# 2332           0.021885                Yelp (Phone) vs YellowPages (Phone)
#
#         Mid_Lat    Mid_Long  Match_Comments  Manual_Match Manual_Lat  \
# 0     40.911066 -111.403867             NaN           NaN        NaN
# 1     40.911066 -111.403867             NaN           NaN        NaN
# 2     40.911066 -111.403867             NaN           NaN        NaN
# 3     40.911066 -111.403867             NaN           NaN        NaN
# 4     40.911066 -111.403867             NaN           NaN        NaN
# ...         ...         ...             ...           ...        ...
# 2328  39.906665 -122.195276             NaN           NaN        NaN
# 2329        NaN         NaN             NaN           NaN        NaN
# 2330        NaN         NaN             NaN           NaN        NaN
# 2331  41.646968 -122.528414             NaN           NaN        NaN
# 2332  41.646968 -122.528414             NaN           NaN        NaN
#
#       Manual_Long
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 2328          NaN
# 2329          NaN
# 2330          NaN
# 2331          NaN
# 2332          NaN
#
# [2333 rows x 151 columns]

# %%
# Check available columns
print("Available columns:")
print(df.columns.tolist())

# Check for the specific columns we need
required_cols = ['Manual_Lat', 'Manual_Long', 'Mid_Lat', 'Mid_Long']
for col in required_cols:
    if col in df.columns:
        print(f"✓ {col} exists")
    else:
        print(f"✗ {col} NOT FOUND")
        
# Check for similar column names
print("\nColumns containing 'lat' or 'long':")
lat_long_cols = [col for col in df.columns if 'lat' in col.lower() or 'long' in col.lower()]
for col in lat_long_cols:
    print(f"  {col}")
# Out:
# Available columns:
# ['clean_line1', 'clean_line2', 'line3', 'city', 'zip_code', 'label', 'phone', 'year', 'major_city', 'state', 'chain', 'address_standardized_ON_parenthesis', 'address_standardized_OFF_parenthesis', 'Address_Type', 'Exit_Number', 'Exit_From_Address', 'Exit_From_Label', 'Flagged', 'Flag_Reason', 'Is_Unclear_OCR', 'Main_Road', 'Secondary_Road', 'Exit_Number_2', 'Exit_Number_3', 'Tertiary_Road', 'phone_scraped_matches_row_ids', 'ZIP_scraped_matches_row_ids', 'City_scraped_matches_row_ids', 'Exit_scraped_matches_row_ids', 'State_scraped_matches_row_ids', 'Road_scraped_matches_row_ids', 'Chain_scraped_matches_row_ids', 'Label_scraped_matches_row_ids', 'all_matches', 'Phone_scraped_matches_row_ids', 'has_phone_match', 'ZIP_scraped_matches_row_ids_parsed', 'State_scraped_matches_row_ids_parsed', 'City_scraped_matches_row_ids_parsed', 'Exit_scraped_matches_row_ids_parsed', 'Road_scraped_matches_row_ids_parsed', 'Label_scraped_matches_row_ids_parsed', 'Chain_scraped_matches_row_ids_parsed', 'Scraped_zipcode_to_label_match_rate', 'Scraped_phone_match_rate', 'Phone_Yelp_matches_row_ids', 'Yelp_phone_match_rate', 'place_identifier(year)', 'Phone_Yellowpages_matches_row_ids', 'Yellowbook_phone_match_rate', 'Webscraped_Phone_state_id', 'Webscraped_Phone_state', 'Webscraped_Phone_name', 'Webscraped_Phone_full_url', 'Webscraped_Phone_stop_type', 'Webscraped_Phone_Chain', 'Webscraped_Phone_Latitude', 'Webscraped_Phone_Longitude', 'Webscraped_Phone_LD_URL', 'Webscraped_Phone_LD_Latitude', 'Webscraped_Phone_LD_Longitude', 'Webscraped_Phone_Highway', 'Webscraped_Phone_Exit', 'Webscraped_Phone_Street Address', 'Webscraped_Phone_City', 'Webscraped_Phone_State', 'Webscraped_Phone_Postal Code', 'Webscraped_Phone_Phone', 'Webscraped_Phone_Fax', 'Webscraped_Phone_Phone 2', 'Webscraped_Phone_Phone 3', 'Webscraped_Phone_Phone 4', 'Webscraped_Phone_Phone 5', 'Webscraped_Phone_Mile Marker', 'Webscraped_Phone_Road Name', 'Webscraped_Phone_https', 'Webscraped_Phone_http', 'Webscraped_Place_Match', 'Webscraped_PlacedMatched_state_id', 'Webscraped_PlacedMatched_state', 'Webscraped_PlacedMatched_name', 'Webscraped_PlacedMatched_full_url', 'Webscraped_PlacedMatched_stop_type', 'Webscraped_PlacedMatched_Chain', 'Webscraped_PlacedMatched_Latitude', 'Webscraped_PlacedMatched_Longitude', 'Webscraped_PlacedMatched_LD_URL', 'Webscraped_PlacedMatched_LD_Latitude', 'Webscraped_PlacedMatched_LD_Longitude', 'Webscraped_PlacedMatched_Highway', 'Webscraped_PlacedMatched_Exit', 'Webscraped_PlacedMatched_Street Address', 'Webscraped_PlacedMatched_City', 'Webscraped_PlacedMatched_State', 'Webscraped_PlacedMatched_Postal Code', 'Webscraped_PlacedMatched_Phone', 'Webscraped_PlacedMatched_Fax', 'Webscraped_PlacedMatched_Phone 2', 'Webscraped_PlacedMatched_Phone 3', 'Webscraped_PlacedMatched_Phone 4', 'Webscraped_PlacedMatched_Phone 5', 'Webscraped_PlacedMatched_Mile Marker', 'Webscraped_PlacedMatched_Road Name', 'Webscraped_PlacedMatched_https', 'Webscraped_PlacedMatched_http', 'Yelp_Original_Phone', 'Yelp_Name', 'Yelp_Rating', 'Yelp_Review_Count', 'Yelp_Address', 'Yelp_City', 'Yelp_State', 'Yelp_Zip_Code', 'Yelp_Phone', 'Yelp_Categories', 'Yelp_Latitude', 'Yelp_Longitude', 'Yelp_Price', 'Yelp_Is_Closed', 'Yelp_URL', 'YellowPages_ADDRESS', 'YellowPages_AKA', 'YellowPages_BUSINESS_NAME', 'YellowPages_BUSINESS_URL', 'YellowPages_CATEGORIES', 'YellowPages_EXTRA_PHONES', 'YellowPages_FORMATTED_PHONE', 'YellowPages_JSONLD_CITY_1', 'YellowPages_JSONLD_LAT_1', 'YellowPages_JSONLD_LNG_1', 'YellowPages_JSONLD_NAME_1', 'YellowPages_JSONLD_PHONE_1', 'YellowPages_JSONLD_STATE_1', 'YellowPages_JSONLD_STREET_1', 'YellowPages_JSONLD_ZIP_1', 'YellowPages_ORIGINAL_PHONE', 'YellowPages_PHONE', 'YellowPages_SCRAPED_AT', 'YellowPages_SEARCH_URL', 'YellowPages_STATUS', 'YellowPages_WEBSITE', 'max_distance_miles', 'max_distance_sources', 'min_distance_miles', 'min_distance_sources', 'Mid_Lat', 'Mid_Long', 'Match_Comments', 'Manual_Match', 'Manual_Lat', 'Manual_Long']
# ✓ Manual_Lat exists
# ✓ Manual_Long exists
# ✓ Mid_Lat exists
# ✓ Mid_Long exists
#
# Columns containing 'lat' or 'long':
#   Webscraped_Phone_Latitude
#   Webscraped_Phone_Longitude
#   Webscraped_Phone_LD_Latitude
#   Webscraped_Phone_LD_Longitude
#   Webscraped_PlacedMatched_Latitude
#   Webscraped_PlacedMatched_Longitude
#   Webscraped_PlacedMatched_LD_Latitude
#   Webscraped_PlacedMatched_LD_Longitude
#   Yelp_Latitude
#   Yelp_Longitude
#   YellowPages_JSONLD_LAT_1
#   Mid_Lat
#   Mid_Long
#   Manual_Lat
#   Manual_Long

# %%
# Create Final_Lat and Final_Long columns
# Priority: Manual_Lat/Manual_Long first, then Mid_Lat/Mid_Long as fallback

import numpy as np

# Initialize the Final columns
df['Final_Lat'] = np.nan
df['Final_Long'] = np.nan

# Check if the required columns exist
required_cols = ['Manual_Lat', 'Manual_Long', 'Mid_Lat', 'Mid_Long']
missing_cols = [col for col in required_cols if col not in df.columns]

if missing_cols:
    print(f"ERROR: Missing columns: {missing_cols}")
    print("Please check the column names in your dataframe.")
else:
    # Apply the logic: Manual first, then Mid as fallback
    
    # Step 1: Use Manual_Lat/Manual_Long where available
    manual_mask = df['Manual_Lat'].notna() & df['Manual_Long'].notna()
    df.loc[manual_mask, 'Final_Lat'] = df.loc[manual_mask, 'Manual_Lat']
    df.loc[manual_mask, 'Final_Long'] = df.loc[manual_mask, 'Manual_Long']
    
    # Step 2: Use Mid_Lat/Mid_Long where Final is still empty
    mid_mask = df['Final_Lat'].isna() & df['Mid_Lat'].notna() & df['Mid_Long'].notna()
    df.loc[mid_mask, 'Final_Lat'] = df.loc[mid_mask, 'Mid_Lat']
    df.loc[mid_mask, 'Final_Long'] = df.loc[mid_mask, 'Mid_Long']
    
    # Check results
    print("Results:")
    print(f"Total rows: {len(df)}")
    print(f"Rows with Manual coordinates used: {manual_mask.sum()}")
    print(f"Rows with Mid coordinates used: {mid_mask.sum()}")
    print(f"Rows with Final coordinates: {df['Final_Lat'].notna().sum()}")
    print(f"Rows without Final coordinates: {df['Final_Lat'].isna().sum()}")
    
    # Check if there are any rows without final coordinates
    missing_final = df['Final_Lat'].isna().sum()
    if missing_final > 0:
        print(f"\n⚠️  WARNING: {missing_final} rows do not have Final coordinates!")
        print("These rows are missing both Manual and Mid coordinates.")
        
        # Show which rows are missing coordinates
        missing_mask = df['Final_Lat'].isna()
        print(f"\nRows missing Final coordinates (showing first 10):")
        print(df[missing_mask][['clean_line1', 'Manual_Lat', 'Manual_Long', 'Mid_Lat', 'Mid_Long']].head(10))
    else:
        print("\n✅ SUCCESS: All rows have Final coordinates!")
# Out:
# Results:
# Total rows: 2333
# Rows with Manual coordinates used: 79
# Rows with Mid coordinates used: 2197
# Rows with Final coordinates: 2276
# Rows without Final coordinates: 57
#
# ⚠️  WARNING: 57 rows do not have Final coordinates!
# These rows are missing both Manual and Mid coordinates.
#
# Rows missing Final coordinates (showing first 10):
#                                             clean_line1  Manual_Lat  \
# 1129                   Kern City , E - Z Trip ( Shell )         NaN
# 1536      American Fork , 84003 Hart's Fuel Stop ( 66 )         NaN
# 1537      American Fork , 84003 Hart's Fuel Stop ( 66 )         NaN
# 1538      American Fork , 84003 Hart's Fuel Stop ( 66 )         NaN
# 1552     E Lindon , 84062 Pirate Petroleum ( Sinclair )         NaN
# 1573  West Valley City , 84128 JoAnn's Gearjammer Tr...         NaN
# 1574  Valley City , 84128 JoAnn's Gearjammer Truck S...         NaN
# 1575  West Valley City , 84128 JoAnn's Gearjammer Tr...         NaN
# 1626                Beaver , 84713 High Country Chevron         NaN
# 1627             B HBeaver , 84713 High Country Chevron         NaN
#
#       Manual_Long  Mid_Lat  Mid_Long
# 1129          NaN      NaN       NaN
# 1536          NaN      NaN       NaN
# 1537          NaN      NaN       NaN
# 1538          NaN      NaN       NaN
# 1552          NaN      NaN       NaN
# 1573          NaN      NaN       NaN
# 1574          NaN      NaN       NaN
# 1575          NaN      NaN       NaN
# 1626          NaN      NaN       NaN
# 1627          NaN      NaN       NaN

# %%
# Fill missing Final_Lat and Final_Long using coordinates from nearby rows with same place_identifier(year)

def fill_missing_coordinates_from_nearby(df):
    """
    Fill missing Final_Lat and Final_Long by looking for nearby rows with the same place_identifier(year)
    that have valid coordinates.
    """
    filled_count = 0
    
    # Find rows with missing Final coordinates
    missing_mask = df['Final_Lat'].isna() | df['Final_Long'].isna()
    missing_indices = df[missing_mask].index.tolist()
    
    print(f"Found {len(missing_indices)} rows with missing Final coordinates")
    
    for idx in missing_indices:
        # Get the place_identifier for this row
        place_id = df.loc[idx, 'place_identifier(year)']
        
        if pd.isna(place_id):
            print(f"Row {idx}: No place_identifier available, skipping")
            continue
            
        print(f"\nProcessing row {idx} with place_identifier: {place_id}")
        
        # Find all rows with the same place_identifier that have valid coordinates
        same_place_mask = (df['place_identifier(year)'] == place_id) & \
                         (df['Final_Lat'].notna()) & \
                         (df['Final_Long'].notna())
        
        same_place_indices = df[same_place_mask].index.tolist()
        
        if not same_place_indices:
            print(f"  No rows with same place_identifier and valid coordinates found")
            continue
            
        # Find the nearest row(s) by index distance
        distances = [(abs(idx - other_idx), other_idx) for other_idx in same_place_indices]
        distances.sort()  # Sort by distance
        
        # Use the nearest row with valid coordinates
        nearest_distance, nearest_idx = distances[0]
        
        # Copy coordinates from the nearest row
        df.loc[idx, 'Final_Lat'] = df.loc[nearest_idx, 'Final_Lat']
        df.loc[idx, 'Final_Long'] = df.loc[nearest_idx, 'Final_Long']
        
        filled_count += 1
        print(f"  ✅ Filled from row {nearest_idx} (distance: {nearest_distance})")
        print(f"     Coordinates: ({df.loc[nearest_idx, 'Final_Lat']}, {df.loc[nearest_idx, 'Final_Long']})")
    
    return filled_count

# Execute the function
print("=== FILLING MISSING COORDINATES FROM NEARBY ROWS ===")
filled = fill_missing_coordinates_from_nearby(df)

# Check results after filling
missing_after = (df['Final_Lat'].isna() | df['Final_Long'].isna()).sum()
print(f"\n=== RESULTS ===")
print(f"Coordinates filled: {filled}")
print(f"Rows still missing coordinates: {missing_after}")

if missing_after > 0:
    print(f"\nRows still missing Final coordinates:")
    still_missing_mask = df['Final_Lat'].isna() | df['Final_Long'].isna()
    missing_details = df[still_missing_mask][['clean_line1', 'place_identifier(year)', 'Final_Lat', 'Final_Long']].head(10)
    print(missing_details)
# Out:
# === FILLING MISSING COORDINATES FROM NEARBY ROWS ===
# Found 57 rows with missing Final coordinates
#
# Processing row 1129 with place_identifier: 189
#   ✅ Filled from row 1128 (distance: 1)
#      Coordinates: (35.354686, -119.3312805)
#
# Processing row 1536 with place_identifier: 257
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1537 with place_identifier: 257
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1538 with place_identifier: 257
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1552 with place_identifier: 263
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1573 with place_identifier: 270
#   ✅ Filled from row 1576 (distance: 3)
#      Coordinates: (41.4854237, -112.0576307)
#
# Processing row 1574 with place_identifier: 270
#   ✅ Filled from row 1573 (distance: 1)
#      Coordinates: (41.4854237, -112.0576307)
#
# Processing row 1575 with place_identifier: 270
#   ✅ Filled from row 1574 (distance: 1)
#      Coordinates: (41.4854237, -112.0576307)
#
# Processing row 1626 with place_identifier: 288
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1627 with place_identifier: 288
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1628 with place_identifier: 288
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1645 with place_identifier: 293
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1646 with place_identifier: 293
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1647 with place_identifier: 293
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1723 with place_identifier: 316
#   ✅ Filled from row 1724 (distance: 1)
#      Coordinates: (32.9496495, -112.7058285)
#
# Processing row 1764 with place_identifier: 328
#   ✅ Filled from row 1767 (distance: 3)
#      Coordinates: (32.125681, -110.873714)
#
# Processing row 1765 with place_identifier: 328
#   ✅ Filled from row 1764 (distance: 1)
#      Coordinates: (32.125681, -110.873714)
#
# Processing row 1766 with place_identifier: 328
#   ✅ Filled from row 1765 (distance: 1)
#      Coordinates: (32.125681, -110.873714)
#
# Processing row 1774 with place_identifier: 330
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1778 with place_identifier: 331
#   ✅ Filled from row 1777 (distance: 1)
#      Coordinates: (34.941290575869104, -111.649818441744)
#
# Processing row 1779 with place_identifier: 331
#   ✅ Filled from row 1778 (distance: 1)
#      Coordinates: (34.941290575869104, -111.649818441744)
#
# Processing row 1780 with place_identifier: 331
#   ✅ Filled from row 1779 (distance: 1)
#      Coordinates: (34.941290575869104, -111.649818441744)
#
# Processing row 1781 with place_identifier: 332
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1782 with place_identifier: 332
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1783 with place_identifier: 333
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1784 with place_identifier: 333
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1785 with place_identifier: 333
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1786 with place_identifier: 333
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1858 with place_identifier: 355
#   ✅ Filled from row 1861 (distance: 3)
#      Coordinates: (39.615062, -119.217706)
#
# Processing row 1859 with place_identifier: 355
#   ✅ Filled from row 1858 (distance: 1)
#      Coordinates: (39.615062, -119.217706)
#
# Processing row 1860 with place_identifier: 355
#   ✅ Filled from row 1859 (distance: 1)
#      Coordinates: (39.615062, -119.217706)
#
# Processing row 1877 with place_identifier: 361
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1878 with place_identifier: 361
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1911 with place_identifier: 373
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1925 with place_identifier: 378
#   ✅ Filled from row 1924 (distance: 1)
#      Coordinates: (33.7695, -118.20827)
#
# Processing row 1941 with place_identifier: 384
#   ✅ Filled from row 1943 (distance: 2)
#      Coordinates: (34.133893, -117.924675)
#
# Processing row 1942 with place_identifier: 384
#   ✅ Filled from row 1941 (distance: 1)
#      Coordinates: (34.133893, -117.924675)
#
# Processing row 1988 with place_identifier: 396
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 1989 with place_identifier: 396
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 2109 with place_identifier: 437
#   ✅ Filled from row 2112 (distance: 3)
#      Coordinates: (35.895028, -119.276516)
#
# Processing row 2110 with place_identifier: 437
#   ✅ Filled from row 2109 (distance: 1)
#      Coordinates: (35.895028, -119.276516)
#
# Processing row 2111 with place_identifier: 437
#   ✅ Filled from row 2110 (distance: 1)
#      Coordinates: (35.895028, -119.276516)
#
# Processing row 2131 with place_identifier: 445
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 2158 with place_identifier: 453
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 2159 with place_identifier: 453
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 2160 with place_identifier: 453
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 2197 with place_identifier: 464
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 2198 with place_identifier: 464
#   No rows with same place_identifier and valid coordinates found
#
# Processing row 2215 with place_identifier: 470
#   ✅ Filled from row 2218 (distance: 3)
#      Coordinates: (38.01184355439345, -122.1053842344715)
#
# Processing row 2216 with place_identifier: 470
#   ✅ Filled from row 2215 (distance: 1)
#      Coordinates: (38.01184355439345, -122.1053842344715)
#
# Processing row 2217 with place_identifier: 470
#   ✅ Filled from row 2216 (distance: 1)
#      Coordinates: (38.01184355439345, -122.1053842344715)
#
# Processing row 2246 with place_identifier: 480
#   ✅ Filled from row 2247 (distance: 1)
#      Coordinates: (37.170959, -120.311897)
#
# Processing row 2281 with place_identifier: 491
#   ✅ Filled from row 2284 (distance: 3)
#      Coordinates: (38.463893, -121.822237)
#
# Processing row 2282 with place_identifier: 491
#   ✅ Filled from row 2281 (distance: 1)
#      Coordinates: (38.463893, -121.822237)
#
# Processing row 2283 with place_identifier: 491
#   ✅ Filled from row 2282 (distance: 1)
#      Coordinates: (38.463893, -121.822237)
#
# Processing row 2329 with place_identifier: 506
#   ✅ Filled from row 2331 (distance: 2)
#      Coordinates: (41.64696784946314, -122.52841370582834)
#
# Processing row 2330 with place_identifier: 506
#   ✅ Filled from row 2329 (distance: 1)
#      Coordinates: (41.64696784946314, -122.52841370582834)
#
# === RESULTS ===
# Coordinates filled: 29
# Rows still missing coordinates: 28
#
# Rows still missing Final coordinates:
#                                          clean_line1  place_identifier(year)  \
# 1536   American Fork , 84003 Hart's Fuel Stop ( 66 )                     257
# 1537   American Fork , 84003 Hart's Fuel Stop ( 66 )                     257
# 1538   American Fork , 84003 Hart's Fuel Stop ( 66 )                     257
# 1552  E Lindon , 84062 Pirate Petroleum ( Sinclair )                     263
# 1626             Beaver , 84713 High Country Chevron                     288
# 1627          B HBeaver , 84713 High Country Chevron                     288
# 1628               Beaver , 84713 High Country Shell                     288
# 1645   Saint George , 84770 Premium Oil ( Sinclair )                     293
# 1646              J Saint George , 84770 Premium Oil                     293
# 1647                Saint George , 84770 Premium Oil                     293
#
#       Final_Lat  Final_Long
# 1536        NaN         NaN
# 1537        NaN         NaN
# 1538        NaN         NaN
# 1552        NaN         NaN
# 1626        NaN         NaN
# 1627        NaN         NaN
# 1628        NaN         NaN
# 1645        NaN         NaN
# 1646        NaN         NaN
# 1647        NaN         NaN

# %%
# Final summary of coordinate filling results
print("=== FINAL SUMMARY ===")
total_rows = len(df)
rows_with_final_coords = (df['Final_Lat'].notna() & df['Final_Long'].notna()).sum()
rows_missing_coords = total_rows - rows_with_final_coords

print(f"Total rows in dataset: {total_rows}")
print(f"Rows with Final coordinates: {rows_with_final_coords}")
print(f"Rows still missing coordinates: {rows_missing_coords}")
print(f"Completion rate: {(rows_with_final_coords/total_rows)*100:.1f}%")

if rows_missing_coords > 0:
    print(f"\nSample of rows still missing coordinates:")
    still_missing = df[df['Final_Lat'].isna() | df['Final_Long'].isna()]
    print(still_missing[['clean_line1', 'place_identifier(year)']].head())
# Out:
# === FINAL SUMMARY ===
# Total rows in dataset: 2333
# Rows with Final coordinates: 2305
# Rows still missing coordinates: 28
# Completion rate: 98.8%
#
# Sample of rows still missing coordinates:
#                                          clean_line1  place_identifier(year)
# 1536   American Fork , 84003 Hart's Fuel Stop ( 66 )                     257
# 1537   American Fork , 84003 Hart's Fuel Stop ( 66 )                     257
# 1538   American Fork , 84003 Hart's Fuel Stop ( 66 )                     257
# 1552  E Lindon , 84062 Pirate Petroleum ( Sinclair )                     263
# 1626             Beaver , 84713 High Country Chevron                     288

# %%
df
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 4               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...                                                 ...
# 2328          2 530-824-8767 I-5 Exit 630 ( South Ave )
# 2329  CCorning 2530-824-8770 I-5 Exit 630 ( South Ave )
# 2330          2 530-824-8770 I-5 Exit 630 ( South Ave )
# 2331             530-436-2208 I-5 Exit 766 ( CA A12 E )
# 2332                     530-436-2208 I-5 Exit 766 ( CA
#
#                                       line3       city  zip_code  \
# 0                                        MO  Coalville     84017
# 1                                M <U+25A1>  Coalville     84017
# 2              M <U+2610> <U+2610> <U+2610>  Coalville     84017
# 3                       M <U+25A1> <U+2610>  Coalville     84017
# 4                          D M <U+25A1> D D  Coalville     84017
# ...                                     ...        ...       ...
# 2328                            24 XL 24 24    Corning     96021
# 2329                               XL 24 45        NaN     96021
# 2330                      124 HRS XL 24 HRS    Corning     96021
# 2331           <U+2610><U+2610> XL <U+2610>    Grenada     96038
# 2332  <U+2610><U+2610> XL <U+25A1> <U+2610>    Grenada     96038
#
#                                 label         phone  year major_city state  \
# 0                Holiday Hills ( 66 )  435-336-4421  2006  Coalville    UT
# 1                        Hills ( 66 )  435-336-4421  2007  Coalville    UT
# 2              Holiday Hills ( 66 ) )  435-336-4421  2008  Coalville    UT
# 3                Holiday Hills ( 66 )  435-336-4421  2014  Coalville    UT
# 4                Holiday Hills ( 66 )  435-336-4421  2015  Coalville    UT
# ...                               ...           ...   ...        ...   ...
# 2328         Love's Travel Stop # 410  530-824-8767  2016    Corning    CA
# 2329  Flying J Travel Plaza # 0510154  530-824-8770  2007    Corning    CA
# 2330  Flying J Travel Plaza # 0510154  530-824-8770  2008    Corning    CA
# 2331           3 J's Food Mart ( 76 )  530-436-2208  2014    Grenada    CA
# 2332      3 J's Food Mart ( 76 ) Dr )  530-436-2208  2015    Grenada    CA
#
#       ... min_distance_miles  \
# 0     ...           0.000000
# 1     ...           0.000000
# 2     ...           0.000000
# 3     ...           0.000000
# 4     ...           0.000000
# ...   ...                ...
# 2328  ...           0.000000
# 2329  ...           0.000000
# 2330  ...           0.000000
# 2331  ...           0.021885
# 2332  ...           0.021885
#
#                                    min_distance_sources    Mid_Lat  \
# 0     Truckstopsandservices (Phone) vs truckstopsand...  40.911066
# 1     Truckstopsandservices (Phone) vs truckstopsand...  40.911066
# 2     Truckstopsandservices (Phone) vs truckstopsand...  40.911066
# 3     Truckstopsandservices (Phone) vs truckstopsand...  40.911066
# 4     Truckstopsandservices (Phone) vs truckstopsand...  40.911066
# ...                                                 ...        ...
# 2328  Truckstopsandservices (Phone) vs truckstopsand...  39.906665
# 2329                                                NaN        NaN
# 2330                                                NaN        NaN
# 2331                Yelp (Phone) vs YellowPages (Phone)  41.646968
# 2332                Yelp (Phone) vs YellowPages (Phone)  41.646968
#
#         Mid_Long Match_Comments Manual_Match  Manual_Lat  Manual_Long  \
# 0    -111.403867            NaN          NaN         NaN          NaN
# 1    -111.403867            NaN          NaN         NaN          NaN
# 2    -111.403867            NaN          NaN         NaN          NaN
# 3    -111.403867            NaN          NaN         NaN          NaN
# 4    -111.403867            NaN          NaN         NaN          NaN
# ...          ...            ...          ...         ...          ...
# 2328 -122.195276            NaN          NaN         NaN          NaN
# 2329         NaN            NaN          NaN         NaN          NaN
# 2330         NaN            NaN          NaN         NaN          NaN
# 2331 -122.528414            NaN          NaN         NaN          NaN
# 2332 -122.528414            NaN          NaN         NaN          NaN
#
#       Final_Lat  Final_Long
# 0     40.911066 -111.403867
# 1     40.911066 -111.403867
# 2     40.911066 -111.403867
# 3     40.911066 -111.403867
# 4     40.911066 -111.403867
# ...         ...         ...
# 2328  39.906665 -122.195276
# 2329  41.646968 -122.528414
# 2330  41.646968 -122.528414
# 2331  41.646968 -122.528414
# 2332  41.646968 -122.528414
#
# [2333 rows x 153 columns]

# %%
df[['clean_line1','clean_line2','line3','Yelp_URL', 
    'Webscraped_Phone_full_url', 
    'Webscraped_PlacedMatched_full_url', 
    'YellowPages_SEARCH_URL', 
    'max_distance_miles','max_distance_sources','min_distance_miles','min_distance_sources','place_identifier(year)','Manual_Match']]
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 4               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...                                                 ...
# 2328          2 530-824-8767 I-5 Exit 630 ( South Ave )
# 2329  CCorning 2530-824-8770 I-5 Exit 630 ( South Ave )
# 2330          2 530-824-8770 I-5 Exit 630 ( South Ave )
# 2331             530-436-2208 I-5 Exit 766 ( CA A12 E )
# 2332                     530-436-2208 I-5 Exit 766 ( CA
#
#                                       line3  \
# 0                                        MO
# 1                                M <U+25A1>
# 2              M <U+2610> <U+2610> <U+2610>
# 3                       M <U+25A1> <U+2610>
# 4                          D M <U+25A1> D D
# ...                                     ...
# 2328                            24 XL 24 24
# 2329                               XL 24 45
# 2330                      124 HRS XL 24 HRS
# 2331           <U+2610><U+2610> XL <U+2610>
# 2332  <U+2610><U+2610> XL <U+25A1> <U+2610>
#
#                                                Yelp_URL  \
# 0     https://www.yelp.com/biz/holiday-hills-rv-park...
# 1     https://www.yelp.com/biz/holiday-hills-rv-park...
# 2     https://www.yelp.com/biz/holiday-hills-rv-park...
# 3     https://www.yelp.com/biz/holiday-hills-rv-park...
# 4     https://www.yelp.com/biz/holiday-hills-rv-park...
# ...                                                 ...
# 2328  https://www.yelp.com/biz/loves-travel-stop-cor...
# 2329                                                NaN
# 2330                                                NaN
# 2331  https://www.yelp.com/biz/shell-gas-grenada?adj...
# 2332  https://www.yelp.com/biz/shell-gas-grenada?adj...
#
#                               Webscraped_Phone_full_url  \
# 0     https://www.truckstopsandservices.com/location...
# 1     https://www.truckstopsandservices.com/location...
# 2     https://www.truckstopsandservices.com/location...
# 3     https://www.truckstopsandservices.com/location...
# 4     https://www.truckstopsandservices.com/location...
# ...                                                 ...
# 2328  https://www.truckstopsandservices.com/location...
# 2329                                                NaN
# 2330                                                NaN
# 2331                                                NaN
# 2332                                                NaN
#
#                       Webscraped_PlacedMatched_full_url  \
# 0     https://www.truckstopsandservices.com/location...
# 1     https://www.truckstopsandservices.com/location...
# 2     https://www.truckstopsandservices.com/location...
# 3     https://www.truckstopsandservices.com/location...
# 4     https://www.truckstopsandservices.com/location...
# ...                                                 ...
# 2328  http://www.rvandtravelers.com/location_details...
# 2329                                                NaN
# 2330                                                NaN
# 2331                                                NaN
# 2332                                                NaN
#
#                                  YellowPages_SEARCH_URL  max_distance_miles  \
# 0     https://www.yellowpages.com/search?search_term...            1.828992
# 1     https://www.yellowpages.com/search?search_term...            1.828992
# 2     https://www.yellowpages.com/search?search_term...            1.828992
# 3     https://www.yellowpages.com/search?search_term...            1.828992
# 4     https://www.yellowpages.com/search?search_term...            1.828992
# ...                                                 ...                 ...
# 2328  https://www.yellowpages.com/search?search_term...            0.108357
# 2329  https://www.yellowpages.com/search?search_term...            0.000000
# 2330  https://www.yellowpages.com/search?search_term...            0.000000
# 2331  https://www.yellowpages.com/search?search_term...            0.032823
# 2332  https://www.yellowpages.com/search?search_term...            0.032823
#
#                      max_distance_sources  min_distance_miles  \
# 0     Yelp (Phone) vs YellowPages (Phone)            0.000000
# 1     Yelp (Phone) vs YellowPages (Phone)            0.000000
# 2     Yelp (Phone) vs YellowPages (Phone)            0.000000
# 3     Yelp (Phone) vs YellowPages (Phone)            0.000000
# 4     Yelp (Phone) vs YellowPages (Phone)            0.000000
# ...                                   ...                 ...
# 2328  Yelp (Phone) vs YellowPages (Phone)            0.000000
# 2329                                  NaN            0.000000
# 2330                                  NaN            0.000000
# 2331  Yelp (Phone) vs YellowPages (Phone)            0.021885
# 2332  Yelp (Phone) vs YellowPages (Phone)            0.021885
#
#                                    min_distance_sources  \
# 0     Truckstopsandservices (Phone) vs truckstopsand...
# 1     Truckstopsandservices (Phone) vs truckstopsand...
# 2     Truckstopsandservices (Phone) vs truckstopsand...
# 3     Truckstopsandservices (Phone) vs truckstopsand...
# 4     Truckstopsandservices (Phone) vs truckstopsand...
# ...                                                 ...
# 2328  Truckstopsandservices (Phone) vs truckstopsand...
# 2329                                                NaN
# 2330                                                NaN
# 2331                Yelp (Phone) vs YellowPages (Phone)
# 2332                Yelp (Phone) vs YellowPages (Phone)
#
#       place_identifier(year) Manual_Match
# 0                          1          NaN
# 1                          1          NaN
# 2                          1          NaN
# 3                          1          NaN
# 4                          1          NaN
# ...                      ...          ...
# 2328                     505          NaN
# 2329                     506          NaN
# 2330                     506          NaN
# 2331                     506          NaN
# 2332                     506          NaN
#
# [2333 rows x 13 columns]

# %%
import plotly.express as px

# Check column names to understand the data structure
print("Column names:")
print(df.columns.tolist())

# Check if Final_Lat and Final_Long columns exist
if 'Final_Lat' in df.columns and 'Final_Long' in df.columns:
    print(f"\nDataset shape: {df.shape}")
    print(f"Non-null Final_Lat values: {df['Final_Lat'].notna().sum()}")
    print(f"Non-null Final_Long values: {df['Final_Long'].notna().sum()}")
    
    # Filter out rows with missing coordinates
    plot_df = df.dropna(subset=['Final_Lat', 'Final_Long']).copy()
    
    # Create a color column based on whether Manual_Lat is non-empty
    plot_df['Source_Type'] = 'Automated Geocoding'
    if 'Manual_Lat' in plot_df.columns:
        manual_mask = plot_df['Manual_Lat'].notna()
        plot_df.loc[manual_mask, 'Source_Type'] = 'Manual Coordinates'
        
        manual_count = manual_mask.sum()
        auto_count = len(plot_df) - manual_count
        print(f"\nCoordinate sources:")
        print(f"Manual coordinates: {manual_count}")
        print(f"Automated geocoding: {auto_count}")
    
    # Create the map plot with color differentiation
    fig = px.scatter_mapbox(
        plot_df,
        lat='Final_Lat',
        lon='Final_Long',
        color='Source_Type',
        color_discrete_map={
            'Manual Coordinates': '#FF6B6B',  # Red for manual
            'Automated Geocoding': '#4ECDC4'  # Teal for automated
        },
        zoom=3,
        height=900,
        width=1800,
        title='Final Coordinates Map - Color Coded by Source'
    )
    
    # Update hover template to include source information
    fig.update_traces(
        hovertemplate="<b>%{customdata[0]}</b><br>" +
                     "Latitude: %{lat}<br>" +
                     "Longitude: %{lon}<br>" +
                     "Source: %{customdata[1]}<extra></extra>",
        customdata=plot_df[['clean_line1', 'Source_Type']].values if 'clean_line1' in plot_df.columns else plot_df[['Source_Type', 'Source_Type']].values
    )
    
    fig.update_layout(
        mapbox_style="open-street-map",
        margin={"r":0,"t":0,"l":0,"b":0},
        autosize=True,
        height=900,
        width=1800,
        legend=dict(
            yanchor="top",
            y=0.99,
            xanchor="left",
            x=0.01,
            bgcolor="rgba(255,255,255,0.8)",
            bordercolor="rgba(0,0,0,0.2)",
            borderwidth=1
        )
    )
    
    fig.show()
    
    # Save the map to an HTML file
    fig.write_html(r'9.html')
    print(f"\nMap saved with {len(plot_df)} points")
    
else:
    print("Final_Lat and/or Final_Long columns not found in the dataset")
    print("Available columns with 'lat' or 'long' in the name:")
    lat_long_cols = [col for col in df.columns if 'lat' in col.lower() or 'long' in col.lower()]
    for col in lat_long_cols:
        print(f"  - {col}")
# Out:
# Column names:
# ['clean_line1', 'clean_line2', 'line3', 'city', 'zip_code', 'label', 'phone', 'year', 'major_city', 'state', 'chain', 'address_standardized_ON_parenthesis', 'address_standardized_OFF_parenthesis', 'Address_Type', 'Exit_Number', 'Exit_From_Address', 'Exit_From_Label', 'Flagged', 'Flag_Reason', 'Is_Unclear_OCR', 'Main_Road', 'Secondary_Road', 'Exit_Number_2', 'Exit_Number_3', 'Tertiary_Road', 'phone_scraped_matches_row_ids', 'ZIP_scraped_matches_row_ids', 'City_scraped_matches_row_ids', 'Exit_scraped_matches_row_ids', 'State_scraped_matches_row_ids', 'Road_scraped_matches_row_ids', 'Chain_scraped_matches_row_ids', 'Label_scraped_matches_row_ids', 'all_matches', 'Phone_scraped_matches_row_ids', 'has_phone_match', 'ZIP_scraped_matches_row_ids_parsed', 'State_scraped_matches_row_ids_parsed', 'City_scraped_matches_row_ids_parsed', 'Exit_scraped_matches_row_ids_parsed', 'Road_scraped_matches_row_ids_parsed', 'Label_scraped_matches_row_ids_parsed', 'Chain_scraped_matches_row_ids_parsed', 'Scraped_zipcode_to_label_match_rate', 'Scraped_phone_match_rate', 'Phone_Yelp_matches_row_ids', 'Yelp_phone_match_rate', 'place_identifier(year)', 'Phone_Yellowpages_matches_row_ids', 'Yellowbook_phone_match_rate', 'Webscraped_Phone_state_id', 'Webscraped_Phone_state', 'Webscraped_Phone_name', 'Webscraped_Phone_full_url', 'Webscraped_Phone_stop_type', 'Webscraped_Phone_Chain', 'Webscraped_Phone_Latitude', 'Webscraped_Phone_Longitude', 'Webscraped_Phone_LD_URL', 'Webscraped_Phone_LD_Latitude', 'Webscraped_Phone_LD_Longitude', 'Webscraped_Phone_Highway', 'Webscraped_Phone_Exit', 'Webscraped_Phone_Street Address', 'Webscraped_Phone_City', 'Webscraped_Phone_State', 'Webscraped_Phone_Postal Code', 'Webscraped_Phone_Phone', 'Webscraped_Phone_Fax', 'Webscraped_Phone_Phone 2', 'Webscraped_Phone_Phone 3', 'Webscraped_Phone_Phone 4', 'Webscraped_Phone_Phone 5', 'Webscraped_Phone_Mile Marker', 'Webscraped_Phone_Road Name', 'Webscraped_Phone_https', 'Webscraped_Phone_http', 'Webscraped_Place_Match', 'Webscraped_PlacedMatched_state_id', 'Webscraped_PlacedMatched_state', 'Webscraped_PlacedMatched_name', 'Webscraped_PlacedMatched_full_url', 'Webscraped_PlacedMatched_stop_type', 'Webscraped_PlacedMatched_Chain', 'Webscraped_PlacedMatched_Latitude', 'Webscraped_PlacedMatched_Longitude', 'Webscraped_PlacedMatched_LD_URL', 'Webscraped_PlacedMatched_LD_Latitude', 'Webscraped_PlacedMatched_LD_Longitude', 'Webscraped_PlacedMatched_Highway', 'Webscraped_PlacedMatched_Exit', 'Webscraped_PlacedMatched_Street Address', 'Webscraped_PlacedMatched_City', 'Webscraped_PlacedMatched_State', 'Webscraped_PlacedMatched_Postal Code', 'Webscraped_PlacedMatched_Phone', 'Webscraped_PlacedMatched_Fax', 'Webscraped_PlacedMatched_Phone 2', 'Webscraped_PlacedMatched_Phone 3', 'Webscraped_PlacedMatched_Phone 4', 'Webscraped_PlacedMatched_Phone 5', 'Webscraped_PlacedMatched_Mile Marker', 'Webscraped_PlacedMatched_Road Name', 'Webscraped_PlacedMatched_https', 'Webscraped_PlacedMatched_http', 'Yelp_Original_Phone', 'Yelp_Name', 'Yelp_Rating', 'Yelp_Review_Count', 'Yelp_Address', 'Yelp_City', 'Yelp_State', 'Yelp_Zip_Code', 'Yelp_Phone', 'Yelp_Categories', 'Yelp_Latitude', 'Yelp_Longitude', 'Yelp_Price', 'Yelp_Is_Closed', 'Yelp_URL', 'YellowPages_ADDRESS', 'YellowPages_AKA', 'YellowPages_BUSINESS_NAME', 'YellowPages_BUSINESS_URL', 'YellowPages_CATEGORIES', 'YellowPages_EXTRA_PHONES', 'YellowPages_FORMATTED_PHONE', 'YellowPages_JSONLD_CITY_1', 'YellowPages_JSONLD_LAT_1', 'YellowPages_JSONLD_LNG_1', 'YellowPages_JSONLD_NAME_1', 'YellowPages_JSONLD_PHONE_1', 'YellowPages_JSONLD_STATE_1', 'YellowPages_JSONLD_STREET_1', 'YellowPages_JSONLD_ZIP_1', 'YellowPages_ORIGINAL_PHONE', 'YellowPages_PHONE', 'YellowPages_SCRAPED_AT', 'YellowPages_SEARCH_URL', 'YellowPages_STATUS', 'YellowPages_WEBSITE', 'max_distance_miles', 'max_distance_sources', 'min_distance_miles', 'min_distance_sources', 'Mid_Lat', 'Mid_Long', 'Match_Comments', 'Manual_Match', 'Manual_Lat', 'Manual_Long', 'Final_Lat', 'Final_Long']
#
# Dataset shape: (2333, 153)
# Non-null Final_Lat values: 2305
# Non-null Final_Long values: 2305
# C:\Users\clint\AppData\Local\Temp\ipykernel_17144\1452423562.py:17: DeprecationWarning:
#
# *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
# Map saved with 2305 points

# %%
#save df as 9.csv
df.to_csv(r'9.csv', index=False)

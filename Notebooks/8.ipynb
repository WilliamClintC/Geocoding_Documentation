# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\clint\Desktop\Geocoding_Documentation\Notebooks\5.csv')
df
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...

# %%
df[['clean_line1', 'clean_line2', 'line3', 'Yelp_URL','Yelp_Latitude', 'Yelp_Longitude',
    'Webscraped_Phone_full_url', 'Webscraped_Phone_LD_Latitude', 'Webscraped_Phone_LD_Longitude',
    'Webscraped_PlacedMatched_full_url', 'Webscraped_PlacedMatched_LD_Latitude', 'Webscraped_PlacedMatched_LD_Longitude',
    'YellowPages_SEARCH_URL', 'YellowPages_JSONLD_LAT_1', 'YellowPages_JSONLD_LNG_1',
    'max_distance_miles', 'max_distance_sources', 'min_distance_miles', 'min_distance_sources', 'place_identifier(year)']]
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...

# %%
# Create new columns
df['Match_Comments'] = ''
df['Manual_Match'] = ''
df['Manual_Lat'] = ''
df['Manual_Long'] = ''

# Update the entry for place identifier(year)==92
df.loc[df['place_identifier(year)'] == 92, 'Manual_Match'] = 'https://www.truckstopsandservices.com/location_details.php?id=10277'
df.loc[df['place_identifier(year)'] == 92, 'Manual_Lat'] = 34.728256
df.loc[df['place_identifier(year)'] == 92, 'Manual_Long'] = -114.315187

# Update the entry for place identifier(year)==89
df.loc[df['place_identifier(year)'] == 89, 'Manual_Match'] = 'https://www.truckstopsandservices.com/location_details.php?id=2214'
df.loc[df['place_identifier(year)'] == 89, 'Manual_Lat'] = 35.17617
df.loc[df['place_identifier(year)'] == 89, 'Manual_Long'] = -113.785941

# Update the entry for place identifier(year)==460
df.loc[df['place_identifier(year)'] == 460, 'Manual_Match'] = 'https://www.yellowpages.com/madera-ca/mip/valero-473794351'
df.loc[df['place_identifier(year)'] == 460, 'Manual_Lat'] = 36.923553
df.loc[df['place_identifier(year)'] == 460, 'Manual_Long'] = -120.02618

df.loc[df['place_identifier(year)'] == 499, 'Manual_Match'] = 'https://www.yellowpages.com/dunnigan-ca/mip/united-travel-plaza-566494439'
df.loc[df['place_identifier(year)'] == 499, 'Manual_Lat'] = 38.860195
df.loc[df['place_identifier(year)'] == 499, 'Manual_Long'] = -121.95684

# Update the entry for place identifier(year)==485
df.loc[df['place_identifier(year)'] == 485, 'Manual_Match'] = 'https://www.truckstopsandservices.com/location_details.php?id=10342'
df.loc[df['place_identifier(year)'] == 485, 'Manual_Lat'] = 39.00122
df.loc[df['place_identifier(year)'] == 485, 'Manual_Long'] = -122.893987

df.loc[df['place_identifier(year)'] == 253, 'Manual_Match'] = 'https://www.yelp.com/biz/cottonwood-chevron-cottonwood?adjust_creative=xElCeMfmOucjLmXEMhJkIg&utm_campaign=yelp_api_v3&utm_medium=api_v3_phone_search&utm_source=xElCeMfmOucjLmXEMhJkIg'
df.loc[df['place_identifier(year)'] == 253, 'Manual_Lat'] = 40.370251
df.loc[df['place_identifier(year)'] == 253, 'Manual_Long'] = -122.283625

df.loc[df['place_identifier(year)'] == 277, 'Manual_Match'] = 'https://www.yellowpages.com/ogden-ut/mip/chevron-452413503'
df.loc[df['place_identifier(year)'] == 277, 'Manual_Lat'] = 41.229145
df.loc[df['place_identifier(year)'] == 277, 'Manual_Long'] = -112.006584

df.loc[df['place_identifier(year)'] == 359, 'Match_Comments'] = 'Both places with similar names and same area'

df.loc[df['place_identifier(year)'] == 340, 'Manual_Match'] = 'https://www.truckstopsandservices.com/location_details.php?id=11836'
df.loc[df['place_identifier(year)'] == 340, 'Manual_Lat'] = 37.365133
df.loc[df['place_identifier(year)'] == 340, 'Manual_Long'] = -115.159914

df.loc[df['place_identifier(year)'] == 10, 'Manual_Match'] = 'http://www.rvandtravelers.com/location_details.php?id=789'
df.loc[df['place_identifier(year)'] == 10, 'Manual_Lat'] = 40.739716
df.loc[df['place_identifier(year)'] == 10, 'Manual_Long'] = -111.944625
df.loc[df['place_identifier(year)'] == 164, 'Match_Comments'] = 'Too close already'

# Update the entry for place identifier(year)==275
df.loc[df['place_identifier(year)'] == 275, 'Manual_Lat'] = 41.7110875414374
df.loc[df['place_identifier(year)'] == 275, 'Manual_Long'] = -112.179749917386

# Update the entry for place identifier(year)==135
df.loc[df['place_identifier(year)'] == 135, 'Manual_Lat'] = 33.774475
df.loc[df['place_identifier(year)'] == 135, 'Manual_Long'] = -118.25391

# Update the entry for place identifier(year)==273
df.loc[df['place_identifier(year)'] == 273, 'Manual_Lat'] = 41.886516471518895
df.loc[df['place_identifier(year)'] == 273, 'Manual_Long'] = -112.16742385741813

# Update the entry for place identifier(year)==247
df.loc[df['place_identifier(year)'] == 247, 'Manual_Lat'] = 39.740034472254365
df.loc[df['place_identifier(year)'] == 247, 'Manual_Long'] = -122.20339906976407

# Update the entry for place identifier(year)==283
df.loc[df['place_identifier(year)'] == 283, 'Manual_Lat'] = 38.99387382027033
df.loc[df['place_identifier(year)'] == 283, 'Manual_Long'] = -112.32482061895016

# Update the entry for place identifier(year)==477
df.loc[df['place_identifier(year)'] == 477, 'Manual_Lat'] = 37.92484259805216
df.loc[df['place_identifier(year)'] == 477, 'Manual_Long'] = -121.22885038154168

# Update the entry for place identifier(year)==284
df.loc[df['place_identifier(year)'] == 284, 'Manual_Lat'] = 40.05483507466554
df.loc[df['place_identifier(year)'] == 284, 'Manual_Long'] = -111.731102394095
df.loc[df['place_identifier(year)'] == 284, 'Match_Comments'] = 'made a guess match at https://maps.app.goo.gl/yTptgiDPUwDGgGPQ6'

# Update the entry for place identifier(year)==291
df.loc[df['place_identifier(year)'] == 291, 'Manual_Lat'] = 37.0443227914404
df.loc[df['place_identifier(year)'] == 291, 'Manual_Long'] = -112.5258575028404
df.loc[df['place_identifier(year)'] == 291, 'Match_Comments'] = 'mapquest match 217 S 100 E\nKanab, UT 84741'

# Update the entry for place identifier(year)==364
df.loc[df['place_identifier(year)'] == 364, 'Manual_Lat'] = 39.53457785486948
df.loc[df['place_identifier(year)'] == 364, 'Manual_Long'] = -119.78380942956993

# Update the entry for place identifier(year)==389
df.loc[df['place_identifier(year)'] == 389, 'Manual_Lat'] = 32.850239558484
df.loc[df['place_identifier(year)'] == 389, 'Manual_Long'] = -116.95126512698407
df.loc[df['place_identifier(year)'] == 389, 'Match_Comments'] = 'mapquest match, 11427 Woodside Ave\nSantee, CA 92071'

# Update the entry for place identifier(year)==430
df.loc[df['place_identifier(year)'] == 430, 'Manual_Lat'] = 34.220795746324455
df.loc[df['place_identifier(year)'] == 430, 'Manual_Long'] = -119.14231239911598
df.loc[df['place_identifier(year)'] == 430, 'Match_Comments'] = 'guess'

# Update the entry for place identifier(year)==439
df.loc[df['place_identifier(year)'] == 439, 'Manual_Lat'] = 36.086868117908715
df.loc[df['place_identifier(year)'] == 439, 'Manual_Long'] = -119.03872700108509
df.loc[df['place_identifier(year)'] == 439, 'Match_Comments'] = 'truckmap search , https://maps.app.goo.gl/oe8AFnV3CViEC6p67'

# Update the entry for place identifier(year)==443
df.loc[df['place_identifier(year)'] == 443, 'Manual_Lat'] = 35.353927148875115
df.loc[df['place_identifier(year)'] == 443, 'Manual_Long'] = -118.91178276010221
df.loc[df['place_identifier(year)'] == 443, 'Match_Comments'] = 'mapquest, 8311 E Brundage Ln\nBakersfield, CA 93307'

# Display the updated dataframe with the new columns
df[['place_identifier(year)', 'Match_Comments', 'Manual_Match', 'Manual_Lat', 'Manual_Long']].head(10)
# Out:
#    place_identifier(year) Match_Comments Manual_Match Manual_Lat Manual_Long
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# 5                       1
# 6                       2
# 7                       2
# 8                       2
# 9                       2

# %%
df
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...

# %%
#save as 8.csv
df.to_csv(r'8.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\clint\Desktop\Geocoding_Documentation\Notebooks\1.csv')
df
# Out:
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 4               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...                                                 ...
# 2328          2 530-824-8767 I-5 Exit 630 ( South Ave )
# 2329  CCorning 2530-824-8770 I-5 Exit 630 ( South Ave )
# 2330          2 530-824-8770 I-5 Exit 630 ( South Ave )
# 2331             530-436-2208 I-5 Exit 766 ( CA A12 E )
# 2332                     530-436-2208 I-5 Exit 766 ( CA
#
#                                       line3       city  zip_code  \
# 0                                        MO  Coalville     84017
# 1                                M <U+25A1>  Coalville     84017
# 2              M <U+2610> <U+2610> <U+2610>  Coalville     84017
# 3                       M <U+25A1> <U+2610>  Coalville     84017
# 4                          D M <U+25A1> D D  Coalville     84017
# ...                                     ...        ...       ...
# 2328                            24 XL 24 24    Corning     96021
# 2329                               XL 24 45        NaN     96021
# 2330                      124 HRS XL 24 HRS    Corning     96021
# 2331           <U+2610><U+2610> XL <U+2610>    Grenada     96038
# 2332  <U+2610><U+2610> XL <U+25A1> <U+2610>    Grenada     96038
#
#                                 label         phone  year major_city state  \
# 0                Holiday Hills ( 66 )  435-336-4421  2006  Coalville    UT
# 1                        Hills ( 66 )  435-336-4421  2007  Coalville    UT
# 2              Holiday Hills ( 66 ) )  435-336-4421  2008  Coalville    UT
# 3                Holiday Hills ( 66 )  435-336-4421  2014  Coalville    UT
# 4                Holiday Hills ( 66 )  435-336-4421  2015  Coalville    UT
# ...                               ...           ...   ...        ...   ...
# 2328         Love's Travel Stop # 410  530-824-8767  2016    Corning    CA
# 2329  Flying J Travel Plaza # 0510154  530-824-8770  2007    Corning    CA
# 2330  Flying J Travel Plaza # 0510154  530-824-8770  2008    Corning    CA
# 2331           3 J's Food Mart ( 76 )  530-436-2208  2014    Grenada    CA
# 2332      3 J's Food Mart ( 76 ) Dr )  530-436-2208  2015    Grenada    CA
#
#       ...                      YellowPages_JSONLD_PHONE_1  \
# 0     ...  (435) 336-4421; (435) 336-4421; (435) 336-4421
# 1     ...  (435) 336-4421; (435) 336-4421; (435) 336-4421
# 2     ...  (435) 336-4421; (435) 336-4421; (435) 336-4421
# 3     ...  (435) 336-4421; (435) 336-4421; (435) 336-4421
# 4     ...  (435) 336-4421; (435) 336-4421; (435) 336-4421
# ...   ...                                             ...
# 2328  ...  (530) 824-8767; (530) 824-8767; (530) 824-8767
# 2329  ...                                             NaN
# 2330  ...                                             NaN
# 2331  ...  (530) 436-2208; (530) 436-2208; (530) 436-2208
# 2332  ...  (530) 436-2208; (530) 436-2208; (530) 436-2208
#
#      YellowPages_JSONLD_STATE_1  \
# 0                    UT; UT; UT
# 1                    UT; UT; UT
# 2                    UT; UT; UT
# 3                    UT; UT; UT
# 4                    UT; UT; UT
# ...                         ...
# 2328                 CA; CA; CA
# 2329                        NaN
# 2330                        NaN
# 2331                 CA; CA; CA
# 2332                 CA; CA; CA
#
#                             YellowPages_JSONLD_STREET_1  \
# 0                 200 S 200 W; 200 W 500 S; 212 S 500 W
# 1                 200 S 200 W; 200 W 500 S; 212 S 500 W
# 2                 200 S 200 W; 200 W 500 S; 212 S 500 W
# 3                 200 S 200 W; 200 W 500 S; 212 S 500 W
# 4                 200 S 200 W; 200 W 500 S; 212 S 500 W
# ...                                                 ...
# 2328     2120 South Ave; 2120 South Ave; 2120 South Ave
# 2329                                                NaN
# 2330                                                NaN
# 2331  338 Highway A12; 338 County Highway A12; 338 C...
# 2332  338 Highway A12; 338 County Highway A12; 338 C...
#
#        YellowPages_JSONLD_ZIP_1                YellowPages_ORIGINAL_PHONE  \
# 0     84017.0; 84017.0; 84017.0  435-336-4421; 435-336-4421; 435-336-4421
# 1     84017.0; 84017.0; 84017.0  435-336-4421; 435-336-4421; 435-336-4421
# 2     84017.0; 84017.0; 84017.0  435-336-4421; 435-336-4421; 435-336-4421
# 3     84017.0; 84017.0; 84017.0  435-336-4421; 435-336-4421; 435-336-4421
# 4     84017.0; 84017.0; 84017.0  435-336-4421; 435-336-4421; 435-336-4421
# ...                         ...                                       ...
# 2328  96021.0; 96021.0; 96021.0  530-824-8767; 530-824-8767; 530-824-8767
# 2329                        NaN                              530-824-8770
# 2330                        NaN                              530-824-8770
# 2331  96038.0; 96038.0; 96038.0  530-436-2208; 530-436-2208; 530-436-2208
# 2332  96038.0; 96038.0; 96038.0  530-436-2208; 530-436-2208; 530-436-2208
#
#                                       YellowPages_PHONE  \
# 0     (435) 336-4421Call; (435) 336-4421Call; (435) ...
# 1     (435) 336-4421Call; (435) 336-4421Call; (435) ...
# 2     (435) 336-4421Call; (435) 336-4421Call; (435) ...
# 3     (435) 336-4421Call; (435) 336-4421Call; (435) ...
# 4     (435) 336-4421Call; (435) 336-4421Call; (435) ...
# ...                                                 ...
# 2328  (530) 824-8767Call; (530) 824-8767Call; (530) ...
# 2329                                                NaN
# 2330                                                NaN
# 2331  (530) 436-2208Call; (530) 436-2208Call; (530) ...
# 2332  (530) 436-2208Call; (530) 436-2208Call; (530) ...
#
#                                  YellowPages_SCRAPED_AT  \
# 0     2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# 1     2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# 2     2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# 3     2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# 4     2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# ...                                                 ...
# 2328  2025-07-07T06:22:44.040Z; 2025-07-07T06:22:47....
# 2329                           2025-07-07T06:22:59.220Z
# 2330                           2025-07-07T06:22:59.220Z
# 2331  2025-07-07T06:23:07.965Z; 2025-07-07T06:23:11....
# 2332  2025-07-07T06:23:07.965Z; 2025-07-07T06:23:11....
#
#                                  YellowPages_SEARCH_URL YellowPages_STATUS  \
# 0     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 1     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 2     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 3     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 4     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# ...                                                 ...                ...
# 2328  https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 2329  https://www.yellowpages.com/search?search_term...   no_results_found
# 2330  https://www.yellowpages.com/search?search_term...   no_results_found
# 2331  https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 2332  https://www.yellowpages.com/search?search_term...      nan; nan; nan
#
#                                     YellowPages_WEBSITE
# 0     http://www.phillips66gas.com; https://www.phil...
# 1     http://www.phillips66gas.com; https://www.phil...
# 2     http://www.phillips66gas.com; https://www.phil...
# 3     http://www.phillips66gas.com; https://www.phil...
# 4     http://www.phillips66gas.com; https://www.phil...
# ...                                                 ...
# 2328  http://pilotflyingj.com; http://catscale.com/?...
# 2329                                                NaN
# 2330                                                NaN
# 2331  https://find.shell.com/us/fuel/12367409-338-hi...
# 2332  https://find.shell.com/us/fuel/12367409-338-hi...
#
# [2333 rows x 141 columns]

# %%
# import numpy as np

# # Define allowed states
# allowed_states = {'CA', 'UT', 'NV', 'AZ'}

# def process_row(row):
#     states = str(row['YellowPages_JSONLD_STATE_1']).split(';')
#     lngs = str(row['YellowPages_JSONLD_LNG_1']).split(';')
#     lats = str(row['YellowPages_JSONLD_LAT_1']).split(';')
    
#     # Ensure all lists are the same length
#     max_len = max(len(states), len(lngs), len(lats))
#     states += [''] * (max_len - len(states))
#     lngs += [''] * (max_len - len(lngs))
#     lats += [''] * (max_len - len(lats))

#     for i, state in enumerate(states):
#         state = state.strip()
#         if state and state not in allowed_states:
#             lngs[i] = 'removed'
#             lats[i] = 'removed'

#     # Recombine
#     row['YellowPages_JSONLD_LNG_1'] = '; '.join(lngs)
#     row['YellowPages_JSONLD_LAT_1'] = '; '.join(lats)
#     return row

# df = df.apply(process_row, axis=1)
# df

# %%
# # Generalize: For each entry in YellowPages_JSONLD_ZIP_1, if it mismatches zip_code, set lat and lng to 'removed'
# def fix_lat_lng_on_zip_mismatch_all(row):
#     zip_code = str(row['zip_code']).strip().replace('.0','')
#     yp_zip_list = [z.strip().replace('.0','') for z in str(row['YellowPages_JSONLD_ZIP_1']).split(';')]
#     lat_list = [lat.strip() for lat in str(row['YellowPages_JSONLD_LAT_1']).split(';')]
#     lng_list = [lng.strip() for lng in str(row['YellowPages_JSONLD_LNG_1']).split(';')]

#     # Ensure all lists are the same length
#     max_len = max(len(yp_zip_list), len(lat_list), len(lng_list))
#     yp_zip_list += [''] * (max_len - len(yp_zip_list))
#     lat_list += [''] * (max_len - len(lat_list))
#     lng_list += [''] * (max_len - len(lng_list))

#     for i in range(max_len):
#         if yp_zip_list[i] != zip_code:
#             lat_list[i] = 'removed'
#             lng_list[i] = 'removed'

#     row['YellowPages_JSONLD_LAT_1'] = '; '.join(lat_list)
#     row['YellowPages_JSONLD_LNG_1'] = '; '.join(lng_list)
#     return row

# df = df.apply(fix_lat_lng_on_zip_mismatch_all, axis=1)
# df

# %%
# # For each entry in Webscraped_PlacedMatched_Postal, if it mismatches zip_code, set corresponding lat/lng to 'removed'
# def fix_lat_lng_on_postal_mismatch(row):
#     zip_code = str(row['zip_code']).strip().replace('.0','')
#     postal_list = [z.strip().replace('.0','') for z in str(row.get('Webscraped_PlacedMatched_Postal', '')).split(';')]
#     lat_list = [lat.strip() for lat in str(row.get('Webscraped_PlacedMatched_Latitude', '')).split(';')]
#     lng_list = [lng.strip() for lng in str(row.get('Webscraped_PlacedMatched_Longitude', '')).split(';')]

#     # Ensure all lists are the same length
#     max_len = max(len(postal_list), len(lat_list), len(lng_list))
#     postal_list += [''] * (max_len - len(postal_list))
#     lat_list += [''] * (max_len - len(lat_list))
#     lng_list += [''] * (max_len - len(lng_list))

#     for i in range(len(postal_list)):
#         postal_val = str(postal_list[i]).strip().replace('.0','')
#         zip_val = str(zip_code).strip().replace('.0','')
#         if postal_val != zip_val:
#             lat_list[i] = 'removed'
#             lng_list[i] = 'removed'
#     print(f"Comparing: '{postal_list[i]}' vs '{zip_code}'")
#     row['Webscraped_PlacedMatched_Latitude'] = '; '.join(lat_list)
#     row['Webscraped_PlacedMatched_Longitude'] = '; '.join(lng_list)
#     return row

# df = df.apply(fix_lat_lng_on_postal_mismatch, axis=1)
# df

# %%
# import numpy as np
# from math import radians, cos, sin, asin, sqrt

# # Define the columns and their labels (order matters for connection)
# columns_info = [
#     ('Webscraped_Phone_LD_Latitude', 'Webscraped_Phone_LD_Longitude', 'Truckstopsandservices (Phone)'),
#     ('Webscraped_PlacedMatched_LD_Latitude', 'Webscraped_PlacedMatched_LD_Longitude', 'truckstopsandservices (PlaceMatched)'),
#     ('Yelp_Latitude', 'Yelp_Longitude', 'Yelp (Phone)'),
#     ('YellowPages_JSONLD_LAT_1', 'YellowPages_JSONLD_LNG_1', 'YellowPages (Phone)')
#     # Add more sources here if needed
# ]

# def parse_coords(lat_str, lon_str):
#     exclude = {'nan', '', 'None', 'removed'}
#     lats = [float(x) for x in str(lat_str).split(';') if x.strip() not in exclude]
#     lons = [float(x) for x in str(lon_str).split(';') if x.strip() not in exclude]
#     return list(zip(lats, lons))

# def remove_duplicate_coords(coords):
#     """Remove duplicate coordinates and return unique coordinates"""
#     unique_coords = []
#     for coord in coords:
#         if coord not in unique_coords:
#             unique_coords.append(coord)
#     return unique_coords

# def get_single_coordinate_from_duplicates(coords):
#     """Extract single coordinate from duplicate entries like (37.129772, 37.129772)"""
#     if len(coords) == 1:
#         lat, lon = coords[0]
#         return lat, lon
    
#     # Check if we have duplicate coordinates that represent the same location
#     unique_coords = remove_duplicate_coords(coords)
#     if len(unique_coords) == 1:
#         lat, lon = unique_coords[0]
#         return lat, lon
    
#     return None

# def haversine(lat1, lon1, lat2, lon2):
#     R = 3958.8  # Earth radius in miles
#     dlat = radians(lat2 - lat1)
#     dlon = radians(lon2 - lon1)
#     a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2
#     c = 2 * asin(sqrt(a))
#     return R * c

# def calculate_midpoint(lat1, lon1, lat2, lon2):
#     """Calculate the midpoint between two coordinates"""
#     mid_lat = (lat1 + lat2) / 2
#     mid_lon = (lon1 + lon2) / 2
#     return mid_lat, mid_lon

# max_distances = []
# max_distance_sources = []
# min_distances = []
# min_distance_sources = []
# mid_lats = []
# mid_longs = []

# for idx, row in df.iterrows():
#     # Collect coordinates from each data source
#     source_coords = {}
#     for lat_col, lon_col, label in columns_info:
#         if lat_col in row and lon_col in row:
#             coords = parse_coords(row[lat_col], row[lon_col])
#             if coords:
#                 # Remove duplicate coordinates within the same source
#                 unique_coords = remove_duplicate_coords(coords)
#                 source_coords[label] = unique_coords
    
#     # Check if we have only one data source with coordinates
#     if len(source_coords) == 1:
#         source_name = list(source_coords.keys())[0]
#         coords = source_coords[source_name]
        
#         # Try to get a single coordinate from potential duplicates
#         single_coord = get_single_coordinate_from_duplicates(coords)
#         if single_coord:
#             lat, lon = single_coord
#             max_distances.append(0)
#             max_distance_sources.append(f"Single source: {source_name}")
#             min_distances.append(0)
#             min_distance_sources.append(f"Single source: {source_name}")
#             mid_lats.append(lat)
#             mid_longs.append(lon)
#         else:
#             # Multiple different coordinates in single source - leave without midpoint
#             max_distances.append(0)
#             max_distance_sources.append(f"Single source (multiple coords): {source_name}")
#             min_distances.append(0)
#             min_distance_sources.append(f"Single source (multiple coords): {source_name}")
#             mid_lats.append(None)
#             mid_longs.append(None)
#         continue
    
#     # Original logic for multiple data sources
#     # Compare coordinates across different data sources
#     max_dist = 0
#     min_dist = float('inf')
#     max_source_pair = ""
#     min_source_pair = ""
#     min_coord_pair = None  # Store the coordinate pair for minimum distance
#     source_names = list(source_coords.keys())
    
#     for i in range(len(source_names)):
#         for j in range(i+1, len(source_names)):
#             # Get coordinates from two different sources
#             source1_coords = source_coords[source_names[i]]
#             source2_coords = source_coords[source_names[j]]
            
#             # Compare all coordinates from source1 with all coordinates from source2
#             for lat1, lon1 in source1_coords:
#                 for lat2, lon2 in source2_coords:
#                     dist = haversine(lat1, lon1, lat2, lon2)
#                     if dist > max_dist:
#                         max_dist = dist
#                         max_source_pair = f"{source_names[i]} vs {source_names[j]}"
#                     if dist < min_dist:
#                         min_dist = dist
#                         min_source_pair = f"{source_names[i]} vs {source_names[j]}"
#                         min_coord_pair = ((lat1, lon1), (lat2, lon2))  # Store the coordinate pair
    
#     max_distances.append(max_dist)
#     max_distance_sources.append(max_source_pair)
    
#     # Handle case where no comparisons were made
#     if min_dist == float('inf'):
#         min_dist = 0
#         min_source_pair = ""
#         mid_lat = None
#         mid_lon = None
#     else:
#         # Calculate midpoint for the minimum distance coordinate pair
#         (lat1, lon1), (lat2, lon2) = min_coord_pair
#         mid_lat, mid_lon = calculate_midpoint(lat1, lon1, lat2, lon2)
    
#     min_distances.append(min_dist)
#     min_distance_sources.append(min_source_pair)
#     mid_lats.append(mid_lat)
#     mid_longs.append(mid_lon)

# df['max_distance_miles'] = max_distances
# df['max_distance_sources'] = max_distance_sources
# df['min_distance_miles'] = min_distances
# df['min_distance_sources'] = min_distance_sources
# df['Mid_Lat'] = mid_lats
# df['Mid_Long'] = mid_longs

# # Display some examples of the results
# print("Sample of results with midpoints:")
# sample_df = df[df['min_distance_miles'] >= 0][['min_distance_miles', 'min_distance_sources', 'Mid_Lat', 'Mid_Long']].head(10)
# print(sample_df)

# # Show statistics for single source cases
# single_source_df = df[df['min_distance_sources'].str.contains('Single source', na=False)]
# print(f"\nRecords with single data source: {len(single_source_df)}")
# if len(single_source_df) > 0:
#     print("Single source breakdown:")
#     print(single_source_df['min_distance_sources'].value_counts())

# df

# %%
import numpy as np
from math import radians, cos, sin, asin, sqrt

# Define the columns and their labels - treating Webscraped sources as one
columns_info = [
    # Combine both webscraped sources into one "Webscraped" category
    ([('Webscraped_Phone_LD_Latitude', 'Webscraped_Phone_LD_Longitude'),
      ('Webscraped_PlacedMatched_LD_Latitude', 'Webscraped_PlacedMatched_LD_Longitude')], 'Webscraped'),
    ([('Yelp_Latitude', 'Yelp_Longitude')], 'Yelp (Phone)'),
    ([('YellowPages_JSONLD_LAT_1', 'YellowPages_JSONLD_LNG_1')], 'YellowPages (Phone)')
]

def parse_coords(lat_str, lon_str):
    exclude = {'nan', '', 'None', 'removed'}
    lats = [float(x) for x in str(lat_str).split(';') if x.strip() not in exclude]
    lons = [float(x) for x in str(lon_str).split(';') if x.strip() not in exclude]
    return list(zip(lats, lons))

def remove_duplicate_coords(coords):
    """Remove duplicate coordinates and return unique coordinates"""
    unique_coords = []
    for coord in coords:
        if coord not in unique_coords:
            unique_coords.append(coord)
    return unique_coords

def get_single_coordinate_from_duplicates(coords):
    """Extract single coordinate from duplicate entries like (37.129772, 37.129772)"""
    if len(coords) == 1:
        lat, lon = coords[0]
        return lat, lon
    
    # Check if we have duplicate coordinates that represent the same location
    unique_coords = remove_duplicate_coords(coords)
    if len(unique_coords) == 1:
        lat, lon = unique_coords[0]
        return lat, lon
    
    return None

def haversine(lat1, lon1, lat2, lon2):
    R = 3958.8  # Earth radius in miles
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat/2)**2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a))
    return R * c

def calculate_midpoint(lat1, lon1, lat2, lon2):
    """Calculate the midpoint between two coordinates"""
    mid_lat = (lat1 + lat2) / 2
    mid_lon = (lon1 + lon2) / 2
    return mid_lat, mid_lon

max_distances = []
max_distance_sources = []
min_distances = []
min_distance_sources = []
mid_lats = []
mid_longs = []

for idx, row in df.iterrows():
    # Collect coordinates from each data source
    source_coords = {}
    
    for column_pairs, label in columns_info:
        all_coords = []
        
        # Collect coordinates from all column pairs for this source
        for lat_col, lon_col in column_pairs:
            if lat_col in row and lon_col in row:
                coords = parse_coords(row[lat_col], row[lon_col])
                if coords:
                    all_coords.extend(coords)
        
        if all_coords:
            # Remove duplicate coordinates within the same source
            unique_coords = remove_duplicate_coords(all_coords)
            source_coords[label] = unique_coords
    
    # Check if we have only one data source with coordinates
    if len(source_coords) == 1:
        source_name = list(source_coords.keys())[0]
        coords = source_coords[source_name]
        
        # Try to get a single coordinate from potential duplicates
        single_coord = get_single_coordinate_from_duplicates(coords)
        if single_coord:
            lat, lon = single_coord
            max_distances.append(0)
            max_distance_sources.append(f"Single source: {source_name}")
            min_distances.append(0)
            min_distance_sources.append(f"Single source: {source_name}")
            mid_lats.append(lat)
            mid_longs.append(lon)
        else:
            # Multiple different coordinates in single source - leave without midpoint
            max_distances.append(0)
            max_distance_sources.append(f"Single source (multiple coords): {source_name}")
            min_distances.append(0)
            min_distance_sources.append(f"Single source (multiple coords): {source_name}")
            mid_lats.append(None)
            mid_longs.append(None)
        continue
    
    # Compare coordinates across different data sources
    max_dist = 0
    min_dist = float('inf')
    max_source_pair = ""
    min_source_pair = ""
    min_coord_pair = None  # Store the coordinate pair for minimum distance
    source_names = list(source_coords.keys())
    
    for i in range(len(source_names)):
        for j in range(i+1, len(source_names)):
            # Get coordinates from two different sources
            source1_coords = source_coords[source_names[i]]
            source2_coords = source_coords[source_names[j]]
            
            # Compare all coordinates from source1 with all coordinates from source2
            for lat1, lon1 in source1_coords:
                for lat2, lon2 in source2_coords:
                    dist = haversine(lat1, lon1, lat2, lon2)
                    if dist > max_dist:
                        max_dist = dist
                        max_source_pair = f"{source_names[i]} vs {source_names[j]}"
                    if dist < min_dist:
                        min_dist = dist
                        min_source_pair = f"{source_names[i]} vs {source_names[j]}"
                        min_coord_pair = ((lat1, lon1), (lat2, lon2))  # Store the coordinate pair
    
    max_distances.append(max_dist)
    max_distance_sources.append(max_source_pair)
    
    # Handle case where no comparisons were made
    if min_dist == float('inf'):
        min_dist = 0
        min_source_pair = ""
        mid_lat = None
        mid_lon = None
    else:
        # Calculate midpoint for the minimum distance coordinate pair
        (lat1, lon1), (lat2, lon2) = min_coord_pair
        mid_lat, mid_lon = calculate_midpoint(lat1, lon1, lat2, lon2)
    
    min_distances.append(min_dist)
    min_distance_sources.append(min_source_pair)
    mid_lats.append(mid_lat)
    mid_longs.append(mid_lon)

# Update dataframe with new columns (overwriting previous results)
df['max_distance_miles'] = max_distances
df['max_distance_sources'] = max_distance_sources
df['min_distance_miles'] = min_distances
df['min_distance_sources'] = min_distance_sources
df['Mid_Lat'] = mid_lats
df['Mid_Long'] = mid_longs

# Display some examples of the results
print("Sample of results with combined Webscraped sources:")
sample_df = df[df['min_distance_miles'] >= 0][['min_distance_miles', 'min_distance_sources', 'Mid_Lat', 'Mid_Long']].head(10)
print(sample_df)

# Show statistics for single source cases
single_source_df = df[df['min_distance_sources'].str.contains('Single source', na=False)]
print(f"\nRecords with single data source: {len(single_source_df)}")
if len(single_source_df) > 0:
    print("Single source breakdown:")
    print(single_source_df['min_distance_sources'].value_counts())

# Show comparison between new and old approach
print(f"\n=== COMPARISON SUMMARY ===")
print(f"Now treating Webscraped Phone and PlaceMatched as single 'Webscraped' source")
print(f"Data sources: Webscraped, Yelp (Phone), YellowPages (Phone)")

df
# Out:
# Sample of results with combined Webscraped sources:
#    min_distance_miles               min_distance_sources    Mid_Lat  \
# 0            0.071012         Webscraped vs Yelp (Phone)  40.910948
# 1            0.071012         Webscraped vs Yelp (Phone)  40.910948
# 2            0.071012         Webscraped vs Yelp (Phone)  40.910948
# 3            0.071012         Webscraped vs Yelp (Phone)  40.910948
# 4            0.071012         Webscraped vs Yelp (Phone)  40.910948
# 5            0.071012         Webscraped vs Yelp (Phone)  40.910948
# 6            0.024074  Webscraped vs YellowPages (Phone)  40.487595
# 7            0.024074  Webscraped vs YellowPages (Phone)  40.487595
# 8            0.024074  Webscraped vs YellowPages (Phone)  40.487595
# 9            0.024074  Webscraped vs YellowPages (Phone)  40.487595
#
#      Mid_Long
# 0 -111.404529
# 1 -111.404529
# 2 -111.404529
# 3 -111.404529
# 4 -111.404529
# 5 -111.404529
# 6 -111.408021
# 7 -111.408021
# 8 -111.408021
# 9 -111.408021
#
# Records with single data source: 186
# Single source breakdown:
# min_distance_sources
# Single source: YellowPages (Phone)                      131
# Single source (multiple coords): YellowPages (Phone)     28
# Single source: Webscraped                                17
# Single source: Yelp (Phone)                               9
# Single source (multiple coords): Yelp (Phone)             1
# Name: count, dtype: int64
#
# === COMPARISON SUMMARY ===
# Now treating Webscraped Phone and PlaceMatched as single 'Webscraped' source
# Data sources: Webscraped, Yelp (Phone), YellowPages (Phone)
#                                           clean_line1  \
# 0              Coalville , 84017 Holiday Hills ( 66 )
# 1                      Coalville , 84017 Hills ( 66 )
# 2          D Coalville , 84017 Holiday Hills ( 66 ) )
# 3          D Coalville ( 84017 ) Holiday Hills ( 66 )
# 4          D Coalville ( 84017 ) Holiday Hills ( 66 )
# ...                                               ...
# 2328       Corning ( 96021 ) Love's Travel Stop # 410
# 2329          , 96021 Flying J Travel Plaza # 0510154
# 2330  Corning , 96021 Flying J Travel Plaza # 0510154
# 2331       A Grenada ( 96038 ) 3 J's Food Mart ( 76 )
# 2332  A Grenada ( 96038 ) 3 J's Food Mart ( 76 ) Dr )
#
#                                             clean_line2  \
# 0                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 1         435-336-4421 I-80 Holiday Exit 162 ( UT 280 )
# 2               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# 3                 435-336-4421 I-80 Exit 162 ( UT 280 )
# 4               4 435-336-4421 I-80 Exit 162 ( UT 280 )
# ...                                                 ...
# 2328          2 530-824-8767 I-5 Exit 630 ( South Ave )
# 2329  CCorning 2530-824-8770 I-5 Exit 630 ( South Ave )
# 2330          2 530-824-8770 I-5 Exit 630 ( South Ave )
# 2331             530-436-2208 I-5 Exit 766 ( CA A12 E )
# 2332                     530-436-2208 I-5 Exit 766 ( CA
#
#                                       line3       city  zip_code  \
# 0                                        MO  Coalville     84017
# 1                                M <U+25A1>  Coalville     84017
# 2              M <U+2610> <U+2610> <U+2610>  Coalville     84017
# 3                       M <U+25A1> <U+2610>  Coalville     84017
# 4                          D M <U+25A1> D D  Coalville     84017
# ...                                     ...        ...       ...
# 2328                            24 XL 24 24    Corning     96021
# 2329                               XL 24 45        NaN     96021
# 2330                      124 HRS XL 24 HRS    Corning     96021
# 2331           <U+2610><U+2610> XL <U+2610>    Grenada     96038
# 2332  <U+2610><U+2610> XL <U+25A1> <U+2610>    Grenada     96038
#
#                                 label         phone  year major_city state  \
# 0                Holiday Hills ( 66 )  435-336-4421  2006  Coalville    UT
# 1                        Hills ( 66 )  435-336-4421  2007  Coalville    UT
# 2              Holiday Hills ( 66 ) )  435-336-4421  2008  Coalville    UT
# 3                Holiday Hills ( 66 )  435-336-4421  2014  Coalville    UT
# 4                Holiday Hills ( 66 )  435-336-4421  2015  Coalville    UT
# ...                               ...           ...   ...        ...   ...
# 2328         Love's Travel Stop # 410  530-824-8767  2016    Corning    CA
# 2329  Flying J Travel Plaza # 0510154  530-824-8770  2007    Corning    CA
# 2330  Flying J Travel Plaza # 0510154  530-824-8770  2008    Corning    CA
# 2331           3 J's Food Mart ( 76 )  530-436-2208  2014    Grenada    CA
# 2332      3 J's Food Mart ( 76 ) Dr )  530-436-2208  2015    Grenada    CA
#
#       ...                             YellowPages_SCRAPED_AT  \
# 0     ...  2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# 1     ...  2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# 2     ...  2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# 3     ...  2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# 4     ...  2025-07-07T04:11:50.073Z; 2025-07-07T04:11:53....
# ...   ...                                                ...
# 2328  ...  2025-07-07T06:22:44.040Z; 2025-07-07T06:22:47....
# 2329  ...                           2025-07-07T06:22:59.220Z
# 2330  ...                           2025-07-07T06:22:59.220Z
# 2331  ...  2025-07-07T06:23:07.965Z; 2025-07-07T06:23:11....
# 2332  ...  2025-07-07T06:23:07.965Z; 2025-07-07T06:23:11....
#
#                                  YellowPages_SEARCH_URL YellowPages_STATUS  \
# 0     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 1     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 2     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 3     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 4     https://www.yellowpages.com/search?search_term...      nan; nan; nan
# ...                                                 ...                ...
# 2328  https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 2329  https://www.yellowpages.com/search?search_term...   no_results_found
# 2330  https://www.yellowpages.com/search?search_term...   no_results_found
# 2331  https://www.yellowpages.com/search?search_term...      nan; nan; nan
# 2332  https://www.yellowpages.com/search?search_term...      nan; nan; nan
#
#                                     YellowPages_WEBSITE max_distance_miles  \
# 0     http://www.phillips66gas.com; https://www.phil...           1.828992
# 1     http://www.phillips66gas.com; https://www.phil...           1.828992
# 2     http://www.phillips66gas.com; https://www.phil...           1.828992
# 3     http://www.phillips66gas.com; https://www.phil...           1.828992
# 4     http://www.phillips66gas.com; https://www.phil...           1.828992
# ...                                                 ...                ...
# 2328  http://pilotflyingj.com; http://catscale.com/?...           0.108357
# 2329                                                NaN           0.000000
# 2330                                                NaN           0.000000
# 2331  https://find.shell.com/us/fuel/12367409-338-hi...           0.032823
# 2332  https://find.shell.com/us/fuel/12367409-338-hi...           0.032823
#
#                      max_distance_sources  min_distance_miles  \
# 0     Yelp (Phone) vs YellowPages (Phone)            0.071012
# 1     Yelp (Phone) vs YellowPages (Phone)            0.071012
# 2     Yelp (Phone) vs YellowPages (Phone)            0.071012
# 3     Yelp (Phone) vs YellowPages (Phone)            0.071012
# 4     Yelp (Phone) vs YellowPages (Phone)            0.071012
# ...                                   ...                 ...
# 2328  Yelp (Phone) vs YellowPages (Phone)            0.026483
# 2329                                                 0.000000
# 2330                                                 0.000000
# 2331  Yelp (Phone) vs YellowPages (Phone)            0.021885
# 2332  Yelp (Phone) vs YellowPages (Phone)            0.021885
#
#                      min_distance_sources    Mid_Lat    Mid_Long
# 0              Webscraped vs Yelp (Phone)  40.910948 -111.404529
# 1              Webscraped vs Yelp (Phone)  40.910948 -111.404529
# 2              Webscraped vs Yelp (Phone)  40.910948 -111.404529
# 3              Webscraped vs Yelp (Phone)  40.910948 -111.404529
# 4              Webscraped vs Yelp (Phone)  40.910948 -111.404529
# ...                                   ...        ...         ...
# 2328    Webscraped vs YellowPages (Phone)  39.906627 -122.195031
# 2329                                             NaN         NaN
# 2330                                             NaN         NaN
# 2331  Yelp (Phone) vs YellowPages (Phone)  41.646968 -122.528414
# 2332  Yelp (Phone) vs YellowPages (Phone)  41.646968 -122.528414
#
# [2333 rows x 147 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Create a comprehensive visualization of min_distance_miles distribution
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Remove rows where min_distance_miles is 0 (no comparisons made)
filtered_df = df[df['min_distance_miles'] > 0]

print(f"Total records: {len(df)}")
print(f"Records with distance comparisons: {len(filtered_df)}")
print(f"Records with no distance comparisons: {len(df) - len(filtered_df)}")
print("\nBasic statistics for min_distance_miles (excluding zeros):")
print(filtered_df['min_distance_miles'].describe())

# 1. Histogram
axes[0,0].hist(filtered_df['min_distance_miles'], bins=50, edgecolor='black', alpha=0.7)
axes[0,0].set_title('Distribution of Minimum Distance Between Sources')
axes[0,0].set_xlabel('Minimum Distance (miles)')
axes[0,0].set_ylabel('Frequency')
axes[0,0].grid(True, alpha=0.3)

# 2. Box plot
axes[0,1].boxplot(filtered_df['min_distance_miles'])
axes[0,1].set_title('Box Plot of Minimum Distance')
axes[0,1].set_ylabel('Minimum Distance (miles)')
axes[0,1].grid(True, alpha=0.3)

# 3. Log scale histogram (for better visualization of distribution)
axes[1,0].hist(filtered_df['min_distance_miles'], bins=50, edgecolor='black', alpha=0.7)
axes[1,0].set_yscale('log')
axes[1,0].set_title('Distribution (Log Scale Y-axis)')
axes[1,0].set_xlabel('Minimum Distance (miles)')
axes[1,0].set_ylabel('Frequency (log scale)')
axes[1,0].grid(True, alpha=0.3)

# 4. Cumulative distribution
sorted_distances = np.sort(filtered_df['min_distance_miles'])
cumulative = np.arange(1, len(sorted_distances) + 1) / len(sorted_distances)
axes[1,1].plot(sorted_distances, cumulative, linewidth=2)
axes[1,1].set_title('Cumulative Distribution')
axes[1,1].set_xlabel('Minimum Distance (miles)')
axes[1,1].set_ylabel('Cumulative Probability')
axes[1,1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Total records: 2333
# Records with distance comparisons: 2074
# Records with no distance comparisons: 259
#
# Basic statistics for min_distance_miles (excluding zeros):
# count    2074.000000
# mean        1.309761
# std        21.040377
# min         0.000276
# 25%         0.014029
# 50%         0.025332
# 75%         0.042374
# max       391.141056
# Name: min_distance_miles, dtype: float64

# %%
# More detailed analysis of min_distance_miles
print("=== DETAILED ANALYSIS OF MINIMUM DISTANCES ===\n")

# Percentile analysis
percentiles = [1, 5, 10, 25, 50, 75, 90, 95, 99]
print("Percentile breakdown:")
for p in percentiles:
    value = np.percentile(filtered_df['min_distance_miles'], p)
    print(f"{p:2d}th percentile: {value:.4f} miles")

print(f"\nRange: {filtered_df['min_distance_miles'].min():.4f} to {filtered_df['min_distance_miles'].max():.4f} miles")

# Distance ranges analysis
print("\n=== DISTANCE RANGE ANALYSIS ===")
ranges = [
    (0, 0.01, "Very close (< 0.01 miles = ~53 feet)"),
    (0.01, 0.1, "Close (0.01-0.1 miles = ~53-528 feet)"),
    (0.1, 0.5, "Moderate (0.1-0.5 miles = ~528-2640 feet)"),
    (0.5, 1.0, "Far (0.5-1.0 miles)"),
    (1.0, float('inf'), "Very far (> 1.0 miles)")
]

for min_dist, max_dist, label in ranges:
    if max_dist == float('inf'):
        count = len(filtered_df[filtered_df['min_distance_miles'] >= min_dist])
    else:
        count = len(filtered_df[(filtered_df['min_distance_miles'] >= min_dist) & 
                                (filtered_df['min_distance_miles'] < max_dist)])
    percentage = (count / len(filtered_df)) * 100
    print(f"{label}: {count:3d} records ({percentage:5.1f}%)")

# Most common source pairs for minimum distances
print(f"\n=== MOST COMMON SOURCE PAIRS FOR MINIMUM DISTANCES ===")
source_counts = filtered_df['min_distance_sources'].value_counts()
print("Top 10 source pairs:")
for source, count in source_counts.head(10).items():
    percentage = (count / len(filtered_df)) * 100
    print(f"{source}: {count:3d} occurrences ({percentage:4.1f}%)")

# Records with exceptionally small distances (potential duplicates)
very_close = filtered_df[filtered_df['min_distance_miles'] < 0.001]  # Less than ~5 feet
if len(very_close) > 0:
    print(f"\n=== EXCEPTIONALLY CLOSE COORDINATES (< 0.001 miles = ~5 feet) ===")
    print(f"Found {len(very_close)} records with distances < 5 feet")
    print("These might indicate duplicate or nearly identical coordinates:")
    for idx, row in very_close.head(10).iterrows():
        print(f"Row {idx}: {row['min_distance_miles']:.6f} miles - {row['min_distance_sources']}")
# Out:
# === DETAILED ANALYSIS OF MINIMUM DISTANCES ===
#
# Percentile breakdown:
#  1th percentile: 0.0009 miles
#  5th percentile: 0.0053 miles
# 10th percentile: 0.0083 miles
# 25th percentile: 0.0140 miles
# 50th percentile: 0.0253 miles
# 75th percentile: 0.0424 miles
# 90th percentile: 0.0700 miles
# 95th percentile: 0.0973 miles
# 99th percentile: 8.8058 miles
#
# Range: 0.0003 to 391.1411 miles
#
# === DISTANCE RANGE ANALYSIS ===
# Very close (< 0.01 miles = ~53 feet): 345 records ( 16.6%)
# Close (0.01-0.1 miles = ~53-528 feet): 1628 records ( 78.5%)
# Moderate (0.1-0.5 miles = ~528-2640 feet):  51 records (  2.5%)
# Far (0.5-1.0 miles):  10 records (  0.5%)
# Very far (> 1.0 miles):  40 records (  1.9%)
#
# === MOST COMMON SOURCE PAIRS FOR MINIMUM DISTANCES ===
# Top 10 source pairs:
# Webscraped vs YellowPages (Phone): 741 occurrences (35.7%)
# Webscraped vs Yelp (Phone): 706 occurrences (34.0%)
# Yelp (Phone) vs YellowPages (Phone): 627 occurrences (30.2%)
#
# === EXCEPTIONALLY CLOSE COORDINATES (< 0.001 miles = ~5 feet) ===
# Found 31 records with distances < 5 feet
# These might indicate duplicate or nearly identical coordinates:
# Row 492: 0.000484 miles - Webscraped vs Yelp (Phone)
# Row 493: 0.000484 miles - Webscraped vs Yelp (Phone)
# Row 494: 0.000484 miles - Webscraped vs Yelp (Phone)
# Row 495: 0.000484 miles - Webscraped vs Yelp (Phone)
# Row 496: 0.000484 miles - Webscraped vs Yelp (Phone)
# Row 497: 0.000484 miles - Webscraped vs Yelp (Phone)
# Row 1038: 0.000887 miles - Yelp (Phone) vs YellowPages (Phone)
# Row 1039: 0.000887 miles - Yelp (Phone) vs YellowPages (Phone)
# Row 1040: 0.000887 miles - Yelp (Phone) vs YellowPages (Phone)
# Row 1041: 0.000887 miles - Yelp (Phone) vs YellowPages (Phone)

# %%
#save df as 5.csv
df.to_csv(r'C:\Users\clint\Desktop\Geocoding_Documentation\Notebooks\5.csv', index=False)

# %%
# # Let's examine some single source examples to verify our logic
# single_source_examples = df[df['min_distance_sources'].str.contains('Single source', na=False)].head(10)

# print("=== SINGLE SOURCE EXAMPLES ===")
# for idx, row in single_source_examples.iterrows():
#     print(f"\nRow {idx}:")
#     print(f"Source: {row['min_distance_sources']}")
#     print(f"Mid_Lat: {row['Mid_Lat']}, Mid_Long: {row['Mid_Long']}")
    
#     # Show the original coordinate data
#     for lat_col, lon_col, label in columns_info:
#         if lat_col in row and lon_col in row:
#             lat_val = str(row[lat_col])
#             lon_val = str(row[lon_col])
#             if lat_val not in ['nan', '', 'None'] and lon_val not in ['nan', '', 'None']:
#                 print(f"  {label}: Lat={lat_val}, Lon={lon_val}")

# # Show perfect example of the requested functionality
# print("\n=== PERFECT EXAMPLES OF DUPLICATE COORDINATE HANDLING ===")
# examples_found = 0
# for idx, row in df.iterrows():
#     if examples_found >= 3:  # Just show a few examples
#         break
    
#     # Look for YellowPages entries with duplicate coordinates
#     if 'YellowPages_JSONLD_LAT_1' in row and 'YellowPages_JSONLD_LNG_1' in row:
#         lat_str = str(row['YellowPages_JSONLD_LAT_1'])
#         lon_str = str(row['YellowPages_JSONLD_LNG_1'])
        
#         # Check if this matches the exact pattern mentioned: "37.129772; 37.129772"
#         if ';' in lat_str and ';' in lon_str:
#             lat_parts = [x.strip() for x in lat_str.split(';')]
#             lon_parts = [x.strip() for x in lon_str.split(';')]
            
#             # Check if all latitude values are the same and all longitude values are the same
#             if len(set(lat_parts)) == 1 and len(set(lon_parts)) == 1 and lat_parts[0] != '':
#                 examples_found += 1
#                 print(f"\nRow {idx} - EXACT EXAMPLE OF REQUESTED FUNCTIONALITY:")
#                 print(f"  Original data: Lat={lat_str}, Lon={lon_str}")
#                 print(f"  Recognized as: Single coordinate {lat_parts[0]}, {lon_parts[0]}")
#                 print(f"  Result: Mid_Lat={row['Mid_Lat']}, Mid_Long={row['Mid_Long']}")
#                 print(f"  Source: {row['min_distance_sources']}")

# print(f"\n=== SUMMARY ===")
# print(f"Total records processed: {len(df)}")
# print(f"Records with single data source: {len(df[df['min_distance_sources'].str.contains('Single source', na=False)])}")
# print(f"Records with multiple data sources: {len(df[~df['min_distance_sources'].str.contains('Single source', na=False) & (df['min_distance_sources'] != '')])}")
# print(f"Records with no valid coordinates: {len(df[df['min_distance_sources'] == ''])}")
# Out:
# === SINGLE SOURCE EXAMPLES ===
#
# Row 288:
# Source: Single source: YellowPages (Phone)
# Mid_Lat: 37.129772, Mid_Long: -113.525925
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 11
#       8 print(f"Mid_Lat: {row['Mid_Lat']}, Mid_Long: {row['Mid_Long']}")
#      10 # Show the original coordinate data
# ---> 11 for lat_col, lon_col, label in columns_info:
#      12     if lat_col in row and lon_col in row:
#      13         lat_val = str(row[lat_col])
#
# ValueError: not enough values to unpack (expected 3, got 2)
